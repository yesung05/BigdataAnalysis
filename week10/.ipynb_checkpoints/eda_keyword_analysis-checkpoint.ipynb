# %% [markdown]
# 실습 4-B: 공격 키워드 빈도 분석 (터미널 / Jupyter 버전)
# ======================================================
# 1교시에서 배운 공격 키워드가 실제 CSIC 2010 데이터에
# 얼마나 나타나는지 확인합니다.
#
# Streamlit 없이 터미널에서 바로 실행할 수 있는 버전입니다.
# (Streamlit 대시보드 버전: streamlit run eda_visualization.py)
#
# 실행 방법 (둘 다 가능):
#   - 스크립트 모드:    python eda_keyword_analysis.py
#   - Jupyter 셀 모드:  VSCode에서 # %% 셀 위 'Run Cell' 클릭 (또는 Shift+Enter)

# %%
# %% [Setup] 패키지 import 및 데이터 로드
import pandas as pd
import os
import re
from urllib.parse import unquote

print("=" * 65)
print("  [실습 4-B] 공격 키워드 빈도 분석")
print("=" * 65)

# Jupyter 셀 모드에서도 동작하도록 __file__ 처리
try:
    SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    SCRIPT_DIR = os.getcwd()

data_path = os.path.join(SCRIPT_DIR, "csic2010_requests.csv")
if not os.path.exists(data_path):
    print(f"\n  !! csic2010_requests.csv 파일이 없습니다.")
    print(f"  >> 먼저 download_csic2010.py를 실행하세요.")
    raise SystemExit

df = pd.read_csv(data_path)
print(f"\n  데이터 로드: {len(df):,}건")

# URL 디코딩 + 결합 텍스트
df["url_decoded"] = df["url"].apply(lambda x: unquote(str(x), encoding="latin-1"))
df["body_decoded"] = df["body"].fillna("").apply(lambda x: unquote(str(x), encoding="latin-1"))
df["full_text"] = df["url_decoded"] + " " + df["body_decoded"]
# Out:
# =================================================================
#   [실습 4-B] 공격 키워드 빈도 분석
# =================================================================
#
#   데이터 로드: 10,000건

# %%
df.tail(20)
# Out:
#           label method                                                url  \
# 9980     Normal   POST                        /tienda1/publico/entrar.jsp
# 9981     Normal   POST                        /tienda1/publico/vaciar.jsp
# 9982     Normal    GET                         /tienda1/global/titulo.jsp
# 9983  Anomalous   POST                       /tienda1/miembros/editar.jsp
# 9984     Normal    GET                        /tienda1/miembros/fotos.jsp
# 9985     Normal   POST                        /tienda1/publico/vaciar.jsp
# 9986     Normal    GET  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9987  Anomalous    GET           /tienda1/publico/caracteristicas.jsp.OLD
# 9988     Normal    GET  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9989     Normal    GET               /tienda1/miembros/imagenes/ogono.jpg
# 9990  Anomalous    GET  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9991     Normal    GET                       /tienda1/global/creditos.jsp
# 9992     Normal    GET  /tienda1/publico/pagar.jsp?modo=insertar&preci...
# 9993     Normal   POST                      /tienda1/publico/registro.jsp
# 9994  Anomalous    GET  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9995     Normal    GET                        /tienda1/global/estilos.css
# 9996     Normal    GET                      /tienda1/imagenes/cmenbul.gif
# 9997     Normal    GET                         /tienda1/global/titulo.jsp
# 9998     Normal   POST                        /tienda1/publico/anadir.jsp
# 9999  Anomalous   POST               /tienda1/publico/caracteristicas.jsp
#
#      http_version            host  \
# 9980     HTTP/1.1  localhost:8080
# 9981     HTTP/1.1  localhost:8080
# 9982     HTTP/1.1  localhost:8080
# 9983     HTTP/1.1  localhost:8080
# 9984     HTTP/1.1  localhost:8080
# 9985     HTTP/1.1  localhost:8080
# 9986     HTTP/1.1  localhost:8080
# 9987     HTTP/1.1  localhost:8080
# 9988     HTTP/1.1  localhost:8080
# 9989     HTTP/1.1  localhost:8080
# 9990     HTTP/1.1  localhost:8080
# 9991     HTTP/1.1  localhost:8080
# 9992     HTTP/1.1  localhost:8080
# 9993     HTTP/1.1  localhost:8080
# 9994     HTTP/1.1  localhost:8080
# 9995     HTTP/1.1  localhost:8080
# 9996     HTTP/1.1  localhost:8080
# 9997     HTTP/1.1  localhost:8080
# 9998     HTTP/1.1  localhost:8080
# 9999     HTTP/1.1  localhost:8080
#
#                                              user_agent    pragma  \
# 9980  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9981  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9982  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9983  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9984  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9985  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9986  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9987  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9988  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9989  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9990  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9991  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9992  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9993  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9994  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9995  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9996  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9997  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9998  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
# 9999  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache
#
#      cache_control                                             accept  \
# 9980      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9981      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9982      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9983      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9984      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9985      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9986      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9987      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9988      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9989      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9990      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9991      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9992      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9993      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9994      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9995      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9996      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9997      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9998      no-cache  text/xml,application/xml,application/xhtml+xml...
# 9999      no-cache  text/xml,application/xml,application/xhtml+xml...
#
#                        accept_encoding  ...  \
# 9980  x-gzip, x-deflate, gzip, deflate  ...
# 9981  x-gzip, x-deflate, gzip, deflate  ...
# 9982  x-gzip, x-deflate, gzip, deflate  ...
# 9983  x-gzip, x-deflate, gzip, deflate  ...
# 9984  x-gzip, x-deflate, gzip, deflate  ...
# 9985  x-gzip, x-deflate, gzip, deflate  ...
# 9986  x-gzip, x-deflate, gzip, deflate  ...
# 9987  x-gzip, x-deflate, gzip, deflate  ...
# 9988  x-gzip, x-deflate, gzip, deflate  ...
# 9989  x-gzip, x-deflate, gzip, deflate  ...
# 9990  x-gzip, x-deflate, gzip, deflate  ...
# 9991  x-gzip, x-deflate, gzip, deflate  ...
# 9992  x-gzip, x-deflate, gzip, deflate  ...
# 9993  x-gzip, x-deflate, gzip, deflate  ...
# 9994  x-gzip, x-deflate, gzip, deflate  ...
# 9995  x-gzip, x-deflate, gzip, deflate  ...
# 9996  x-gzip, x-deflate, gzip, deflate  ...
# 9997  x-gzip, x-deflate, gzip, deflate  ...
# 9998  x-gzip, x-deflate, gzip, deflate  ...
# 9999  x-gzip, x-deflate, gzip, deflate  ...
#
#                                            cookie  \
# 9980  JSESSIONID=6A9E8962E0E31D4B3FCCC24A3AF86C3B
# 9981  JSESSIONID=862C13AF8D570864AC2AAF0BD8B61339
# 9982  JSESSIONID=F37E996B0F96713381B14A43E1AE5DC7
# 9983  JSESSIONID=40FF98C7374C2495311F834D6E9B3C70
# 9984  JSESSIONID=4F8E28F643212BD1A8E725B3ED26C4A1
# 9985  JSESSIONID=B3C81D5FEF9DD87B4F9EA0BAD8858358
# 9986  JSESSIONID=7866EF9DEBDA21FC507499CA39DA6554
# 9987  JSESSIONID=73C4B5C89CE06CFC7365EBB7CF302DC2
# 9988  JSESSIONID=528064EBC1097362623937B25B11D8FC
# 9989  JSESSIONID=F3321A9E9DBDF4B7B10D00783B332F80
# 9990  JSESSIONID=3DE8C520664A4FDABB4B5DA66114CF99
# 9991  JSESSIONID=AA550941D099C243F59ADC606B79E0A1
# 9992  JSESSIONID=C55C41F4ED1CAE1FBD9AA9DE652B1D54
# 9993  JSESSIONID=4525FAFBB2BE88A7ABDC4495E2D3C0B4
# 9994  JSESSIONID=F0BE3E5D591EC21C2B7068181A7D1E2F
# 9995  JSESSIONID=E920E69471A011579F0720FCD90BFF2E
# 9996  JSESSIONID=36E12256C60662E0852525C2A204DEED
# 9997  JSESSIONID=25D7022C3B580D1D6689811BF346DCB5
# 9998  JSESSIONID=2436A5157F43E5E3DECE11F1C390CFF8
# 9999  JSESSIONID=AAECDF742DAEAD8C3F901AF615560423
#
#                            content_type       content_length  \
# 9980  application/x-www-form-urlencoded   Content-Length: 33
# 9981  application/x-www-form-urlencoded   Content-Length: 17
# 9982                                NaN                  NaN
# 9983  application/x-www-form-urlencoded  Content-Length: 246
# 9984                                NaN                  NaN
# 9985  application/x-www-form-urlencoded   Content-Length: 17
# 9986                                NaN                  NaN
# 9987                                NaN                  NaN
# 9988                                NaN                  NaN
# 9989                                NaN                  NaN
# 9990                                NaN                  NaN
# 9991                                NaN                  NaN
# 9992                                NaN                  NaN
# 9993  application/x-www-form-urlencoded  Content-Length: 248
# 9994                                NaN                  NaN
# 9995                                NaN                  NaN
# 9996                                NaN                  NaN
# 9997                                NaN                  NaN
# 9998  application/x-www-form-urlencoded   Content-Length: 71
# 9999  application/x-www-form-urlencoded    Content-Length: 5
#
#              connection                                               body  \
# 9980  Connection: close                  errorMsg=Credenciales+incorrectas
# 9981  Connection: close                                  B2=Vaciar+carrito
# 9982              close                                                NaN
# 9983  Connection: close  modo=registro&login=keefer&password=ma2e32&nom...
# 9984              close                                                NaN
# 9985  Connection: close                                  B2=Vaciar+carrito
# 9986              close                                                NaN
# 9987              close                                                NaN
# 9988              close                                                NaN
# 9989              close                                                NaN
# 9990              close                                                NaN
# 9991              close                                                NaN
# 9992              close                                                NaN
# 9993  Connection: close  modo=registro&login=guntar&password=descapotar...
# 9994              close                                                NaN
# 9995              close                                                NaN
# 9996              close                                                NaN
# 9997              close                                                NaN
# 9998  Connection: close  id=3&nombre=Queso+Manchego&precio=85&cantidad=...
# 9999  Connection: close                                              idA=2
#
#      classification                                        raw_request  \
# 9980              0  POST /tienda1/publico/entrar.jsp HTTP/1.1\nHos...
# 9981              0  POST /tienda1/publico/vaciar.jsp HTTP/1.1\nHos...
# 9982              0  GET /tienda1/global/titulo.jsp HTTP/1.1\nHost:...
# 9983              1  POST /tienda1/miembros/editar.jsp HTTP/1.1\nHo...
# 9984              0  GET /tienda1/miembros/fotos.jsp HTTP/1.1\nHost...
# 9985              0  POST /tienda1/publico/vaciar.jsp HTTP/1.1\nHos...
# 9986              0  GET /tienda1/miembros/editar.jsp?modo=registro...
# 9987              1  GET /tienda1/publico/caracteristicas.jsp.OLD H...
# 9988              0  GET /tienda1/miembros/editar.jsp?modo=registro...
# 9989              0  GET /tienda1/miembros/imagenes/ogono.jpg HTTP/...
# 9990              1  GET /tienda1/miembros/editar.jsp?modo=registro...
# 9991              0  GET /tienda1/global/creditos.jsp HTTP/1.1\nHos...
# 9992              0  GET /tienda1/publico/pagar.jsp?modo=insertar&p...
# 9993              0  POST /tienda1/publico/registro.jsp HTTP/1.1\nH...
# 9994              1  GET /tienda1/miembros/editar.jsp?modo=registro...
# 9995              0  GET /tienda1/global/estilos.css HTTP/1.1\nHost...
# 9996              0  GET /tienda1/imagenes/cmenbul.gif HTTP/1.1\nHo...
# 9997              0  GET /tienda1/global/titulo.jsp HTTP/1.1\nHost:...
# 9998              0  POST /tienda1/publico/anadir.jsp HTTP/1.1\nHos...
# 9999              1  POST /tienda1/publico/caracteristicas.jsp HTTP...
#
#                                             url_decoded  \
# 9980                        /tienda1/publico/entrar.jsp
# 9981                        /tienda1/publico/vaciar.jsp
# 9982                         /tienda1/global/titulo.jsp
# 9983                       /tienda1/miembros/editar.jsp
# 9984                        /tienda1/miembros/fotos.jsp
# 9985                        /tienda1/publico/vaciar.jsp
# 9986  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9987           /tienda1/publico/caracteristicas.jsp.OLD
# 9988  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9989               /tienda1/miembros/imagenes/ogono.jpg
# 9990  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9991                       /tienda1/global/creditos.jsp
# 9992  /tienda1/publico/pagar.jsp?modo=insertar&preci...
# 9993                      /tienda1/publico/registro.jsp
# 9994  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9995                        /tienda1/global/estilos.css
# 9996                      /tienda1/imagenes/cmenbul.gif
# 9997                         /tienda1/global/titulo.jsp
# 9998                        /tienda1/publico/anadir.jsp
# 9999               /tienda1/publico/caracteristicas.jsp
#
#                                            body_decoded  \
# 9980                  errorMsg=Credenciales+incorrectas
# 9981                                  B2=Vaciar+carrito
# 9982
# 9983  modo=registro&login=keefer&password=ma2e32&nom...
# 9984
# 9985                                  B2=Vaciar+carrito
# 9986
# 9987
# 9988
# 9989
# 9990
# 9991
# 9992
# 9993  modo=registro&login=guntar&password=descapotar...
# 9994
# 9995
# 9996
# 9997
# 9998  id=3&nombre=Queso+Manchego&precio=85&cantidad=...
# 9999                                              idA=2
#
#                                               full_text
# 9980  /tienda1/publico/entrar.jsp errorMsg=Credencia...
# 9981      /tienda1/publico/vaciar.jsp B2=Vaciar+carrito
# 9982                        /tienda1/global/titulo.jsp
# 9983  /tienda1/miembros/editar.jsp modo=registro&log...
# 9984                       /tienda1/miembros/fotos.jsp
# 9985      /tienda1/publico/vaciar.jsp B2=Vaciar+carrito
# 9986  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9987          /tienda1/publico/caracteristicas.jsp.OLD
# 9988  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9989              /tienda1/miembros/imagenes/ogono.jpg
# 9990  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9991                      /tienda1/global/creditos.jsp
# 9992  /tienda1/publico/pagar.jsp?modo=insertar&preci...
# 9993  /tienda1/publico/registro.jsp modo=registro&lo...
# 9994  /tienda1/miembros/editar.jsp?modo=registro&log...
# 9995                       /tienda1/global/estilos.css
# 9996                     /tienda1/imagenes/cmenbul.gif
# 9997                        /tienda1/global/titulo.jsp
# 9998  /tienda1/publico/anadir.jsp id=3&nombre=Queso+...
# 9999         /tienda1/publico/caracteristicas.jsp idA=2
#
# [20 rows x 22 columns]

# %%
# %% [1] 공격 키워드 카테고리별 탐지
# ============================================================
# 1. 공격 키워드 카테고리별 탐지
# ============================================================
print(f"\n{'─' * 65}")
print("  [1] 공격 키워드 카테고리별 빈도")
print(f"{'─' * 65}")

attack_categories = {
    "SQL Injection": ["'", "select", "union", "drop", "insert",
                      "delete", "update", "or '", "1=1", "--"],
    "XSS": ["<script", "alert(", "onerror", "<iframe",
            "<img", "javascript:", "onfocus"],
    "Path Traversal": ["../", "..\\", "/etc/passwd", "/etc/shadow"],
    "Command Injection": ["; ", "|", "&&", "/bin/", "cat ", "rm ", "wget"],
    "CRLF Injection": ["%0d", "%0a"],
}

print(f"\n  {'카테고리':<20s} | {'정상':>8s} | {'공격':>8s} | {'공격 집중도':>10s}")
print(f"  {'─' * 20}-+-{'─' * 8}-+-{'─' * 8}-+-{'─' * 10}")

normal_text = df[df["label"] == "Normal"]["full_text"]
attack_text = df[df["label"] == "Anomalous"]["full_text"]

for category, keywords in attack_categories.items():
    normal_count = 0
    attack_count = 0
    for kw in keywords:
        normal_count += normal_text.str.contains(re.escape(kw), case=False, na=False).sum()
        attack_count += attack_text.str.contains(re.escape(kw), case=False, na=False).sum()

    total = normal_count + attack_count
    concentration = attack_count / max(total, 1) * 100
    print(f"  {category:<20s} | {normal_count:>8,} | {attack_count:>8,} | {concentration:>9.1f}%")
# Out:
# ─────────────────────────────────────────────────────────────────
#   [1] 공격 키워드 카테고리별 빈도
# ─────────────────────────────────────────────────────────────────
#
#   카테고리                 |       정상 |       공격 |     공격 집중도
#   ────────────────────-+-────────-+-────────-+-──────────
#   SQL Injection        |      348 |    1,391 |      80.0%
#   XSS                  |        0 |      232 |     100.0%
#   Path Traversal       |        0 |       33 |     100.0%
#   Command Injection    |        0 |       34 |     100.0%
#   CRLF Injection       |        0 |      249 |     100.0%

# %%
# %% [2] 개별 키워드 상세 분석 (공격 빈도 Top 20)
# ============================================================
# 2. 개별 키워드 상세 분석
# ============================================================
print(f"\n{'─' * 65}")
print("  [2] 개별 키워드 상세 빈도 (공격에서 많이 발견된 순)")
print(f"{'─' * 65}")

results = []
for category, keywords in attack_categories.items():
    for kw in keywords:
        n_count = normal_text.str.contains(re.escape(kw), case=False, na=False).sum()
        a_count = attack_text.str.contains(re.escape(kw), case=False, na=False).sum()
        results.append({
            "category": category, "keyword": kw,
            "normal": n_count, "attack": a_count,
        })

result_df = pd.DataFrame(results).sort_values("attack", ascending=False)

print(f"\n  {'키워드':<15s} | {'카테고리':<20s} | {'정상':>6s} | {'공격':>6s}")
print(f"  {'─' * 15}-+-{'─' * 20}-+-{'─' * 6}-+-{'─' * 6}")

for _, row in result_df.head(20).iterrows():
    marker = " ★" if row["attack"] > row["normal"] * 2 else ""
    print(f"  {row['keyword']:<15s} | {row['category']:<20s} | "
          f"{row['normal']:>6,} | {row['attack']:>6,}{marker}")

print(f"\n  ★ = 공격에서 정상보다 2배 이상 많이 발견된 키워드")
# Out:
# ─────────────────────────────────────────────────────────────────
#   [2] 개별 키워드 상세 빈도 (공격에서 많이 발견된 순)
# ─────────────────────────────────────────────────────────────────
#
#   키워드             | 카테고리                 |     정상 |     공격
#   ───────────────-+-────────────────────-+-──────-+-──────
#   '               | SQL Injection        |     19 |    518 ★
#   insert          | SQL Injection        |    327 |    437
#   --              | SQL Injection        |      0 |    309 ★
#   %0a             | CRLF Injection       |      0 |    156 ★
#   <script         | XSS                  |      0 |    106 ★
#   alert(          | XSS                  |      0 |    100 ★
#   %0d             | CRLF Injection       |      0 |     93 ★
#   select          | SQL Injection        |      0 |     37 ★
#   drop            | SQL Injection        |      2 |     35 ★
#   |               | Command Injection    |      0 |     34 ★
#   /etc/passwd     | Path Traversal       |      0 |     33 ★
#   1=1             | SQL Injection        |      0 |     30 ★
#   javascript:     | XSS                  |      0 |     26 ★
#   delete          | SQL Injection        |      0 |     24 ★
#   update          | SQL Injection        |      0 |      1 ★
#   onerror         | XSS                  |      0 |      0
#   or '            | SQL Injection        |      0 |      0
#   union           | SQL Injection        |      0 |      0
#   <iframe         | XSS                  |      0 |      0
#   ../             | Path Traversal       |      0 |      0
#
#   ★ = 공격에서 정상보다 2배 이상 많이 발견된 키워드

# %%
# %% [3] URL 인코딩 패턴 분석
# ============================================================
# 3. URL 인코딩 패턴 분석
# ============================================================
print(f"\n{'─' * 65}")
print("  [3] URL 인코딩 패턴 분석 (인코딩 전 원본 URL 기준)")
print(f"{'─' * 65}")

encoded_patterns = {
    "%27": "'  (작은따옴표 — SQL Injection)",
    "%3C": "<  (꺾쇠 — XSS)",
    "%3E": ">  (꺾쇠 닫기 — XSS)",
    "%2F": "/  (슬래시 — Path Traversal)",
    "%2E": ".  (점 — Path Traversal)",
    "%0D": "CR (캐리지리턴 — CRLF Injection)",
    "%0A": "LF (라인피드 — CRLF Injection)",
    "%20": "   (공백 — SQL 키워드 구분)",
    "%00": "NULL (널바이트 — 우회 시도)",
}

print(f"\n  {'패턴':<6s} | {'의미':<35s} | {'정상':>6s} | {'공격':>6s}")
print(f"  {'─' * 6}-+-{'─' * 35}-+-{'─' * 6}-+-{'─' * 6}")

# 인코딩 전 원본 URL에서 검색
normal_url = df[df["label"] == "Normal"]["url"]
attack_url = df[df["label"] == "Anomalous"]["url"]

for pattern, meaning in encoded_patterns.items():
    n_count = normal_url.str.contains(pattern, case=False, na=False).sum()
    a_count = attack_url.str.contains(pattern, case=False, na=False).sum()
    if n_count + a_count > 0:
        print(f"  {pattern:<6s} | {meaning:<35s} | {n_count:>6,} | {a_count:>6,}")
# Out:
# ─────────────────────────────────────────────────────────────────
#   [3] URL 인코딩 패턴 분석 (인코딩 전 원본 URL 기준)
# ─────────────────────────────────────────────────────────────────
#
#   패턴     | 의미                                  |     정상 |     공격
#   ──────-+-───────────────────────────────────-+-──────-+-──────
#   %27    | '  (작은따옴표 — SQL Injection)          |      6 |    240
#   %3C    | <  (꺾쇠 — XSS)                       |      0 |     94
#   %3E    | >  (꺾쇠 닫기 — XSS)                    |      0 |     94
#   %2F    | /  (슬래시 — Path Traversal)           |    125 |    394

# %%
# %% [4] 접근 경로(Path) 분석
# ============================================================
# 4. 접근 경로(Path) 분석
# ============================================================
print(f"\n{'─' * 65}")
print("  [4] 가장 많이 접근된 경로 (정상 vs 공격)")
print(f"{'─' * 65}")

df["path"] = df["url_decoded"].str.split("?").str[0]

print(f"\n  === 정상 요청 Top 5 ===")
normal_paths = df[df["label"] == "Normal"]["path"].value_counts().head(5)
for path, count in normal_paths.items():
    print(f"    {path:<50s} {count:>6,}건")

print(f"\n  === 공격 요청 Top 5 ===")
attack_paths = df[df["label"] == "Anomalous"]["path"].value_counts().head(5)
for path, count in attack_paths.items():
    print(f"    {path:<50s} {count:>6,}건")
# Out:
# ─────────────────────────────────────────────────────────────────
#   [4] 가장 많이 접근된 경로 (정상 vs 공격)
# ─────────────────────────────────────────────────────────────────
#
#   === 정상 요청 Top 5 ===
#     /tienda1/publico/entrar.jsp                           367건
#     /tienda1/publico/registro.jsp                         352건
#     /tienda1/publico/vaciar.jsp                           348건
#     /tienda1/miembros/editar.jsp                          340건
#     /tienda1/publico/autenticar.jsp                       335건
#
#   === 공격 요청 Top 5 ===
#     /tienda1/publico/registro.jsp                         490건
#     /tienda1/publico/pagar.jsp                            464건
#     /tienda1/miembros/editar.jsp                          460건
#     /tienda1/publico/autenticar.jsp                       447건
#     /tienda1/publico/anadir.jsp                           444건

# %%
# %% [5] URL 길이 비교 (정상 vs 공격)
# ============================================================
# 5. URL 길이 비교
# ============================================================
print(f"\n{'─' * 65}")
print("  [5] URL 길이 비교 (정상 vs 공격)")
print(f"{'─' * 65}")

df["url_length"] = df["url_decoded"].str.len()

for label in ["Normal", "Anomalous"]:
    subset = df[df["label"] == label]["url_length"]
    print(f"\n  {label}:")
    print(f"    평균: {subset.mean():.0f},  중앙값: {subset.median():.0f},  "
          f"최대: {subset.max():,},  표준편차: {subset.std():.0f}")

print(f"\n  >> 공격 요청의 URL이 평균적으로 더 깁니다!")
print(f"     이 차이가 8주차 IQR 이상치 탐지의 근거가 됩니다.")


print(f"\n{'=' * 65}")
print("  키워드 분석 완료!")
print("  Streamlit 대시보드로 시각적 탐색: streamlit run eda_visualization.py")
print(f"{'=' * 65}")
# Out:
# ─────────────────────────────────────────────────────────────────
#   [5] URL 길이 비교 (정상 vs 공격)
# ─────────────────────────────────────────────────────────────────
#
#   Normal:
#     평균: 50,  중앙값: 29,  최대: 328,  표준편차: 60
#
#   Anomalous:
#     평균: 73,  중앙값: 32,  최대: 637,  표준편차: 84
#
#   >> 공격 요청의 URL이 평균적으로 더 깁니다!
#      이 차이가 8주차 IQR 이상치 탐지의 근거가 됩니다.
#
# =================================================================
#   키워드 분석 완료!
#   Streamlit 대시보드로 시각적 탐색: streamlit run eda_visualization.py
# =================================================================
